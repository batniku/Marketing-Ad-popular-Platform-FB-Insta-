# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data=pd.read_csv("Marketing_Sample_Dataset.csv")
data
# Out:
#      index campaign_name ad_name adset_name         spend  impressions  \
# 0       96    Campaign 4    Ad 5    Adset 6   6252.565316        39309
# 1       97    Campaign 4    Ad 5    Adset 6   5509.664684        98919
# 2       98    Campaign 4    Ad 5    Adset 5  10924.877730        87666
# 3       99    Campaign 4    Ad 5    Adset 5   7890.802268       216464
# 4      100    Campaign 4    Ad 3    Adset 6    196.170000         1034
# ..     ...           ...     ...        ...           ...          ...
# 360    502    Campaign 3    Ad 3    Adset 4   2526.720000        11298
# 361    503    Campaign 3    Ad 3    Adset 4   2966.560000        23789
# 362    504    Campaign 3    Ad 3    Adset 4     53.680000          227
# 363    505    Campaign 3    Ad 4    Adset 4    852.100000         3837
# 364    506    Campaign 3    Ad 4    Adset 4     39.420000          473
#
#      clicks         cpm         cpp  unique_ctr       ctr  unique_clicks  \
# ...

# %% [markdown]
# # Data Information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   campaign_name       365 non-null    object
#  1   ad_name             365 non-null    object
#  2   adset_name          365 non-null    object
#  3   spend               365 non-null    float64
#  4   impressions         365 non-null    int64
#  5   clicks              365 non-null    int64
#  6   cpm                 365 non-null    float64
#  7   cpp                 365 non-null    float64
#  8   unique_ctr          365 non-null    float64
#  9   ctr                 365 non-null    float64
#  10  unique_clicks       365 non-null    int64
#  11  date_start          365 non-null    object
#  12  publisher_platform  365 non-null    object
# dtypes: float64(5), int64(3), object(5)
# memory usage: 37.2+ KB

# %%
data.describe()
# Out:
#               spend    impressions       clicks         cpm         cpp  \
# count    365.000000     365.000000   365.000000  365.000000  365.000000
# mean    3695.650548   43533.312329   811.986301  140.488468  155.890731
# std     3421.096469   56062.443137  1461.139814   70.798777   82.942161
# min        0.110000       1.000000     0.000000   12.621503   12.621503
# 25%      651.750000    4001.000000    84.000000   84.789396   86.700913
# 50%     2886.110000   23162.000000   252.000000  134.958368  146.819984
# 75%     5481.390000   55860.000000   812.000000  184.463160  212.846582
# max    12726.392570  318466.000000  8601.000000  580.888889  580.888889
#
#        unique_ctr         ctr  unique_clicks
# count  365.000000  365.000000     365.000000
# mean     1.687505    2.034933     596.619178
# std      1.072585    1.681625     909.759107
# min      0.000000    0.000000       0.000000
# 25%      0.773746    0.890596      62.000000
# 50%      1.662636    1.860142     198.000000
# ...

# %%
data.head(10)
# Out:
#    index campaign_name ad_name adset_name         spend  impressions  clicks  \
# 0     96    Campaign 4    Ad 5    Adset 6   6252.565316        39309     742
# 1     97    Campaign 4    Ad 5    Adset 6   5509.664684        98919    1005
# 2     98    Campaign 4    Ad 5    Adset 5  10924.877730        87666    1695
# 3     99    Campaign 4    Ad 5    Adset 5   7890.802268       216464    1747
# 4    100    Campaign 4    Ad 3    Adset 6    196.170000         1034      31
# 5    101    Campaign 4    Ad 3    Adset 6   3178.790000        30869     362
# 6    102    Campaign 4    Ad 3    Adset 5    215.560000         1261      34
# 7    103    Campaign 4    Ad 3    Adset 5   3239.850000        37235     404
# 8    104    Campaign 1    Ad 2    Adset 1  11983.381910       162881    8305
# 9    105    Campaign 1    Ad 2    Adset 1    308.798087         3390      99
#
#           cpm         cpp  unique_ctr       ctr  unique_clicks  date_start  \
# ...

# %%
# Lets see how all attributes shows publisher platform

sns.pairplot(data,hue="publisher_platform")

# %%
# inference:- company had spent on compaign 4 and compaign 1
# above pairplot shows both compaigns4 and campaign1 are popular on platforms.
# Lets see the camparisons as per attributes.

# %%
sns.set(style="whitegrid")
fig2 = sns.barplot(x=data["campaign_name"], y=data["spend"], hue=data["publisher_platform"], data=data)
fig2.set(xlabel='Campaign', ylabel='Amount Spend')
plt.show()

# %%
# inference :- above plot shows all campaigns are allmost equally populated on platforms with same amount spent.(approx)

# %%
sns.set(style="whitegrid")
fig2 = sns.barplot(x=data["campaign_name"], y=data["unique_ctr"], hue=data["publisher_platform"], data=data)
fig2.set(xlabel='Campaign', ylabel='unique_ctr')
plt.show()

# %%
##Inference:-  # Facebook has highest number of unique _ctr for all campaigns.

# %%
sns.set(style="whitegrid")
fig2 = sns.barplot(x=data["spend"], y=data["campaign_name"], hue=data["publisher_platform"], data=data)
fig2.set(xlabel='spend', ylabel='campaign')
plt.show()

# %%
## Above plot shows investment on campaign platformwise.

# %%
plt.bar(data.campaign_name,data['spend'])
plt.xlabel('campaign')
plt.ylabel('spend')
plt.title('campaign vs spend')
# Out:
# Text(0.5, 1.0, 'campaign vs spend')

# %%
# Inference :- Reduce spending on campaign 4 as campaign 1 is most popular.

# %%
sns.barplot(x='publisher_platform',y='impressions',data=data)
# Out:
# <AxesSubplot:xlabel='publisher_platform', ylabel='impressions'>

# %%
## score of impressions on Instagram is more.

# %%
data.head()
# Out:
#    index campaign_name ad_name adset_name         spend  impressions  clicks  \
# 0     96    Campaign 4    Ad 5    Adset 6   6252.565316        39309     742
# 1     97    Campaign 4    Ad 5    Adset 6   5509.664684        98919    1005
# 2     98    Campaign 4    Ad 5    Adset 5  10924.877730        87666    1695
# 3     99    Campaign 4    Ad 5    Adset 5   7890.802268       216464    1747
# 4    100    Campaign 4    Ad 3    Adset 6    196.170000         1034      31
#
#           cpm         cpp  unique_ctr       ctr  unique_clicks  date_start  \
# 0  159.061928  179.095019    1.787351  1.887608            624  16-05-2021
# 1   55.698750   55.698750    0.953305  1.015983            943  16-05-2021
# 2  124.619325  137.771640    1.789475  1.933475           1419  16-05-2021
# 3   36.453185   37.013351    0.788506  0.807063           1681  16-05-2021
# 4  189.719536  233.535714    2.142857  2.998066             18  16-05-2021
#
#     date_stop publisher_platform
# ...

# %%
plt.bar(data.date_start,data['impressions'])
plt.xlabel('date_start')
plt.ylabel('impressions')
plt.title('Impressions vs Date')

# setting the plot size for all plots
sns.set(rc={'figure.figsize':(16.9,7.27)})

# %%
# This plot check the date on which people had more impressions on both platforms.
# date attribute should be consider which shows on sunday and monday people like to surf and watching ads.

# %%
sns.barplot(x='publisher_platform',y='unique_clicks',data=data)
# Out:
# <AxesSubplot:xlabel='publisher_platform', ylabel='unique_clicks'>

# %%
## facebook has more no.of susbscribers than insta.

# %%
sns.barplot(x='publisher_platform',y='cpm',data=data)
# Out:
# <AxesSubplot:xlabel='publisher_platform', ylabel='cpm'>

# %%
## Facebook has more CPM invested.

# %%
data=pd.read_csv("Marketing_Sample_Dataset.csv")
data
# Out:
#      index campaign_name ad_name adset_name         spend  impressions  \
# 0       96    Campaign 4    Ad 5    Adset 6   6252.565316        39309
# 1       97    Campaign 4    Ad 5    Adset 6   5509.664684        98919
# 2       98    Campaign 4    Ad 5    Adset 5  10924.877730        87666
# 3       99    Campaign 4    Ad 5    Adset 5   7890.802268       216464
# 4      100    Campaign 4    Ad 3    Adset 6    196.170000         1034
# ..     ...           ...     ...        ...           ...          ...
# 360    502    Campaign 3    Ad 3    Adset 4   2526.720000        11298
# 361    503    Campaign 3    Ad 3    Adset 4   2966.560000        23789
# 362    504    Campaign 3    Ad 3    Adset 4     53.680000          227
# 363    505    Campaign 3    Ad 4    Adset 4    852.100000         3837
# 364    506    Campaign 3    Ad 4    Adset 4     39.420000          473
#
#      clicks         cpm         cpp  unique_ctr       ctr  unique_clicks  \
# ...

# %% [markdown]
# # Data cleaning Delete columns such as index,date_stop

# %%
del data['index']

# %%
data
# Out:
#     campaign_name ad_name adset_name         spend  impressions  clicks  \
# 0      Campaign 4    Ad 5    Adset 6   6252.565316        39309     742
# 1      Campaign 4    Ad 5    Adset 6   5509.664684        98919    1005
# 2      Campaign 4    Ad 5    Adset 5  10924.877730        87666    1695
# 3      Campaign 4    Ad 5    Adset 5   7890.802268       216464    1747
# 4      Campaign 4    Ad 3    Adset 6    196.170000         1034      31
# ..            ...     ...        ...           ...          ...     ...
# 360    Campaign 3    Ad 3    Adset 4   2526.720000        11298     199
# 361    Campaign 3    Ad 3    Adset 4   2966.560000        23789     227
# 362    Campaign 3    Ad 3    Adset 4     53.680000          227       2
# 363    Campaign 3    Ad 4    Adset 4    852.100000         3837     147
# 364    Campaign 3    Ad 4    Adset 4     39.420000          473      16
#
#             cpm         cpp  unique_ctr       ctr  unique_clicks  date_start  \
# ...

# %%
del data['date_stop']

# %%
data
# Out:
#     campaign_name ad_name adset_name         spend  impressions  clicks  \
# 0      Campaign 4    Ad 5    Adset 6   6252.565316        39309     742
# 1      Campaign 4    Ad 5    Adset 6   5509.664684        98919    1005
# 2      Campaign 4    Ad 5    Adset 5  10924.877730        87666    1695
# 3      Campaign 4    Ad 5    Adset 5   7890.802268       216464    1747
# 4      Campaign 4    Ad 3    Adset 6    196.170000         1034      31
# ..            ...     ...        ...           ...          ...     ...
# 360    Campaign 3    Ad 3    Adset 4   2526.720000        11298     199
# 361    Campaign 3    Ad 3    Adset 4   2966.560000        23789     227
# 362    Campaign 3    Ad 3    Adset 4     53.680000          227       2
# 363    Campaign 3    Ad 4    Adset 4    852.100000         3837     147
# 364    Campaign 3    Ad 4    Adset 4     39.420000          473      16
#
#             cpm         cpp  unique_ctr       ctr  unique_clicks  date_start  \
# ...

# %%
sns.barplot(x='publisher_platform',y='clicks',data=data)
# Out:
# <AxesSubplot:xlabel='publisher_platform', ylabel='clicks'>

# %%
# No of clicks on ad was more on Facebook.

# %%
sns.barplot(x='publisher_platform',y='ctr',data=data)
# Out:
# <AxesSubplot:xlabel='publisher_platform', ylabel='ctr'>

# %%
## ctr means click through rate:, this  shows % of people who see and click this ads.
## Facebook has excellent ctr score.

# %%
sns.barplot(x='publisher_platform',y='spend',data=data)
# Out:
# <AxesSubplot:xlabel='publisher_platform', ylabel='spend'>

# %%
# When we analyse spend, unique_clicks (unique people) with compaign ad name and adset for both platforms
# we can conclude which one is best platform for ads.

# %%
sns.barplot(x='publisher_platform',y='unique_clicks',data=data)
# Out:
# <AxesSubplot:xlabel='publisher_platform', ylabel='unique_clicks'>

# %%
slices=data.groupby('campaign_name')['clicks'].sum()
slices
# Out:
# campaign_name
# Campaign 1    171357
# Campaign 2     31369
# Campaign 3      3637
# Campaign 4     90012
# Name: clicks, dtype: int64

# %%
cols=['c','m','r','g']
campaign_name=slices.index

plt.pie(slices,
       labels=campaign_name,
       colors=cols,
       startangle=90,
       shadow=True,
       explode=(0,0,0.1,0),
       autopct='%1.1f%%')

plt.title('Highest campaign_no')
plt.legend()

# %% [markdown]
# # Conclusions : -
# ## 1. From given data set,following are the observations :-
# ## 2. Campaign 1 is most effective on Facebook.
# ## 3. All campaigns are almost equally utilized on both platforms with same amount spent.
# ## 4. Reduce spending on campaign 4.
# ## 5.Instagram has less clicks, and ctr and hence to improve ctr score campaign 1 should be utilized. (may be on holidays).
# ## 6. Most number of unique_clicks(Subscribers) are on Facebook.
# ## 7. Most number of clicks is on facebook and most number of unique_ctr is on facebook.
# ## 8. So rather than spending more on facebook platform, increase spends on instagram.
# ## Because Impressions are high on instagram and ctr score is also Good.
# ## 9. Company had spent on compaign 4 and compaign 1.
# ## 10. Both campaign 4 and 1 are popular on platforms and must be promoted.
# ## 11. Action should be taken to Improve ctr  score of campaign 3 and campaign 2 (modifications are required)
# ## 12. Campaign 2 ,ctr is good on instagram and should try to utilize on facebook.
# ## 13. Try to increase no. of subscribers on instagram which will increase ctr score.

# %% [markdown]
# Assumtions:-
#     1.unique_clicks are the unique subscribers.
#     2.ctr is click though rate
#     3.impressions are digital view of ads only
#     4.CTR is the number of clicks that your ad receives divided by the number of times your ad is shown:
#         clicks ÷ impressions = CTR. For example, if you had 5 clicks and 100 impressions, then your CTR would be 5%.
#         A high CTR is a good indication that users find your ads and listings helpful and relevant.
